# %% [markdown]
# Meu primeiro programa em Python

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# Python e uma linguagem fracamente tipada ou seja nao se preocupa em declarar o tipo dela
# exemplo.:

# %%
escola="SenaiJFM"
print(escola)
# Out:
# SenaiJFM

# %% [markdown]
# para descobrir o tipo da variavel basta adicionar um type e o nome da variavel em parenteses como no exemplo abaixo

# %%
type(escola)
# Out:
# str

# %% [markdown]
# O jeito de mandar o usuario escrever na tela é assim.:

# %%
num1 = input('Entre com o 1º valor: ')
print(num1)
# Out:
# Entre com o 1º valor: A
# A

# %% [markdown]
# Por padrao o imput converte em string e para definir um tipo vc tem que adicionar o tipo antes da palavra input e feito entre parenteses como no exemplo abaixo.:

# %%
 num1= int (input("Digite o numero 1: "))
 num2= int (input("DIgite o numero 2 : "))
res=num1+num2
print(res)

# %% [markdown]
# programa que le dois numeros e indica o maior

# %%
num1= int (input("Digite o numero 1: "))
num2= int (input("DIgite o numero 2 : "))

if num1>num2 :
   print(num1)
elif num2>num1 :
   print(num2)
else :
   print("Os dois numeros sao iguais")

# %% [markdown]
# Programa que le usuario e senha e ve se esta correto

# %%
usuario="admin"
senha="admin@123"
num1= input("Digite o usuario : ")
num2= input("DIgite a senha : ")
erro="tente novamente"
while  num1!=usuario and num2!=senha :
   if num1==usuario and num2==senha :
       print("Parabens voce acertou a senha")
       erro="passou"
else :
      print("Senha incorreta tente novamente")
num1= input("Digite o usuario : ")
num2= input("DIgite a senha : ")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-110-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     130   )
#     131   if ephemeral:
# --> 132     _message.blocking_request(
#     133         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
# ...

# %% [markdown]
# programa que ve se o numero e par ou impar

# %%
num=int (input("Digite um numero : "))
if num % 2 == 0 :
  print("o numero",num,"é par")
else :
  print("o numero",num,"é impar")
# Out:
# Digite um numero : 2
# o numero 2 é par
